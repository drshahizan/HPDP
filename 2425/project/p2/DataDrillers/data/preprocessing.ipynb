# %% [markdown]
# # **🧠 Real-Time Sentiment Analysis on Malaysian E-Wallet Reviews**
#
# ---

# %% [markdown]
# **📘 Subject Details**
# **Subject Code:** SECP3133
# **Subject Name:** HIGH PERFORMANCE DATA PROCESSING
# **Session-Sem:** 24/25-2
#
# ---
#
# **👥 Group B - Data Drillers**
#
# | No. | Name                                  | Matric No       |
# |-----|---------------------------------------|-----------------|
# | 1   | MUHAMMAD ANAS BIN MOHD PIKRI         | A21SC0464       |
# | 2   | MULYANI BINTI SARIPUDDIN             | A22EC0223       |
# | 3   | ALIATUL IZZAH BINTI JASMAN           | A22EC0136       |
# | 4   | THEVAN RAJU A/L JEGANATH             | A22EC0286       |

# %% [markdown]
#   - This Colab notebook is part of a real-time big data analytics project focused on sentiment analysis of popular Malaysian e-wallet applications using user reviews from the Google Play Store.
#
#   - The goal is to scrape, clean, and label user reviews (in Bahasa Melayu) from selected e-wallet apps, preparing them for ingestion into a real-time pipeline.

# %% [markdown]
# ## **📱 Apps Covered**
# 1. Touch 'n Go (my.com.tngdigital.ewallet)
#
# 2. Boost (my.com.myboost)
#
# 3. GrabPay (com.grabtaxi.passenger)
#
# 4. Setel (com.setel.mobile)
#
# 5. ShopeePay (com.shopeepay.my)

# %% [markdown]
# ## **Google Play Scrapping**

# %% [markdown]
# ### 1. 📦 Install google-play-scraper
#
# Installs the library used to scrape app details and user reviews from the Google Play Store — no API key required.

# %%
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.5 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# ### 🔗 2. Connect to Google Drive
# Mounts Google Drive to save scraped review data and ensure persistent storage across sessions.

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Set Drive output path
drive_folder = '/content/drive/MyDrive/Project2'  # Change folder name if needed
os.makedirs(drive_folder, exist_ok=True)

OUTPUT_CSV = os.path.join(drive_folder, 'e_wallet_reviews.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 🌐 3. Install langdetect
#
# Installs the langdetect library for automatic language detection of text (supports 55+ languages, including Malay).

# %%
pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=87cd4de564a5d8411d18d0ebde7378b43786e4c0bf3a400c7d9da819091d3563
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %% [markdown]
# ### 🗃️ 4. Scrape E-Wallet Reviews from Google Play (Bahasa Melayu)
#
# This block collects the latest user reviews (in Bahasa Melayu) for five major Malaysian e-wallet apps using google-play-scraper.
# Each review is labeled as positive, neutral, or negative based on the rating, and saved to Google Drive (e_wallet_reviews.csv).

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import os
import time
from datetime import datetime
from google.colab import drive

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define your e-wallet app packages
apps = {
    'TouchNGo': 'my.com.tngdigital.ewallet',
    'Boost': 'my.com.myboost',
    'Grab': 'com.grabtaxi.passenger',
    'Setel': 'com.setel.mobile',
    'Shopee': 'com.shopeepay.my',
}

# Step 3: Set Drive output file path
drive_folder = '/content/drive/MyDrive/Project2'
os.makedirs(drive_folder, exist_ok=True)
OUTPUT_CSV = os.path.join(drive_folder, 'e_wallet_reviews.csv')

# Step 4: Sentiment labeling function
def label_sentiment(score):
    if score >= 4:
        return 'positive'
    elif score == 3:
        return 'neutral'
    else:
        return 'negative'

# Step 5: Start scraping
start_time = time.time()
total_reviews = 0

# Clear old file on start
if os.path.exists(OUTPUT_CSV):
    os.remove(OUTPUT_CSV)

print("🔍 Starting e-wallet reviews scraping (BM only via lang='ms')...\n")

for app_name, package in apps.items():
    print(f"📱 Scraping: {app_name} ({package})")
    continuation_token = None
    batch_count = 0
    app_reviews = 0
    is_first_batch = True

    while True:
        try:
            result, continuation_token = reviews(
                package,
                lang='ms',        # ✅ Only Bahasa Melayu
                country='my',
                sort=Sort.NEWEST,
                count=200,
                continuation_token=continuation_token
            )
        except Exception as e:
            print(f"❌ Error scraping {app_name}: {e}")
            time.sleep(2)
            continue

        if not result:
            break

        batch_count += 1
        print(f"   📦 Batch {batch_count}: {len(result)} reviews")

        rows = []
        for r in result:
            review_content = r.get('content')
            review_content = review_content.strip() if review_content else ""

            rows.append({
                'app': app_name,
                'username': r['userName'],
                'review': review_content,
                'rating': r['score'],
                'sentiment': label_sentiment(r['score']),
                'date': r['at'].strftime('%Y-%m-%d %H:%M:%S')
            })

        if rows:
            df = pd.DataFrame(rows)
            df.to_csv(OUTPUT_CSV, mode='a', header=is_first_batch, index=False, encoding='utf-8-sig')
            is_first_batch = False

            print(f"   💾 Saved {len(rows)} reviews to file.")


            total_reviews += len(rows)
            app_reviews += len(rows)

        if continuation_token is None:
            break

        time.sleep(1)

    print(f"✅ Finished {app_name}: {app_reviews} reviews collected\n")

# End timer
end_time = time.time()
duration = end_time - start_time
print(f"🎉 Scraping complete. Total reviews collected: {total_reviews}")
print(f"⏱️ Total execution time: {duration:.2f} seconds")
print(f"📄 All data saved to: {OUTPUT_CSV}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔍 Starting e-wallet reviews scraping (BM only via lang='ms')...
#
# 📱 Scraping: TouchNGo (my.com.tngdigital.ewallet)
#    📦 Batch 1: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 2: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 3: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 4: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 5: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 6: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 7: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 8: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 9: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 10: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 11: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 12: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 13: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 14: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 15: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 16: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 17: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 18: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 19: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 20: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 21: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 22: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 23: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 24: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 25: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 26: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 27: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 28: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 29: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 30: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 31: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 32: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 33: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 34: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 35: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 36: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 37: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 38: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 39: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 40: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 41: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 42: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 43: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 44: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 45: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 46: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 47: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 48: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 49: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 50: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 51: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 52: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 53: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 54: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 55: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 56: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 57: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 58: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 59: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 60: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 61: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 62: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 63: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 64: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 65: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 66: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 67: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 68: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 69: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 70: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 71: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 72: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 73: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 74: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 75: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 76: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 77: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 78: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 79: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 80: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 81: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 82: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 83: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 84: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 85: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 86: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 87: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 88: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 89: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 90: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 91: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 92: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 93: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 94: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 95: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 96: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 97: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 98: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 99: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 100: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 101: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 102: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 103: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 104: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 105: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 106: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 107: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 108: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 109: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 110: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 111: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 112: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 113: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 114: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 115: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 116: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 117: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 118: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 119: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 120: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 121: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 122: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 123: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 124: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 125: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 126: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 127: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 128: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 129: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 130: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 131: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 132: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 133: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 134: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 135: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 136: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 137: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 138: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 139: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 140: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 141: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 142: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 143: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 144: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 145: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 146: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 147: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 148: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 149: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch
 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 197: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 198: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 199: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 200: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 201: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 202: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 203: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 204: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 205: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 206: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 207: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 208: 31 reviews
#    💾 Saved 31 reviews to file.
# ✅ Finished Grab: 41431 reviews collected
#
# 📱 Scraping: Setel (com.setel.mobile)
#    📦 Batch 1: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 2: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 3: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 4: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 5: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 6: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 7: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 8: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 9: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 10: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 11: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 12: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 13: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 14: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 15: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 16: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 17: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 18: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 19: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 20: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 21: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 22: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 23: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 24: 187 reviews
#    💾 Saved 187 reviews to file.
# ✅ Finished Setel: 4787 reviews collected
#
# 📱 Scraping: Shopee (com.shopeepay.my)
#    📦 Batch 1: 200 reviews
#    💾 Saved 200 reviews to file.
#    📦 Batch 2: 71 reviews
#    💾 Saved 71 reviews to file.
# ✅ Finished Shopee: 271 reviews collected
#
# 🎉 Scraping complete. Total reviews collected: 103318
# ⏱️ Total execution time: 774.25 seconds
# 📄 All data saved to: /content/drive/MyDrive/Project2/e_wallet_reviews.csv

# %% [markdown]
# ## **🧹 Data Cleaning & Preprocessing**
# This section:
#
# Removes empty reviews and emojis
#
# Cleans text by removing punctuation, digits, and stopwords
#
# Converts and filters valid date entries
#
# Saves the final cleaned dataset to Google Drive as cleaned_reviews.csv

# %%
# ✅ Install required libraries
# !pip install emoji

# ✅ Download necessary NLTK data
import nltk
nltk.download('stopwords')

# ✅ Import libraries
import pandas as pd
import re
import emoji
from nltk.corpus import stopwords
from google.colab import drive
import os

# ✅ Step 1: Mount Google Drive
drive.mount('/content/drive')

# ✅ Step 2: Load original BM-only reviews CSV
input_path = '/content/drive/MyDrive/Project2/e_wallet_reviews.csv'
df = pd.read_csv(input_path)

# ✅ Step 3: Drop empty reviews
df.dropna(subset=['review'], inplace=True)

# ✅ Step 4: Get NLTK stopwords (English for now, can customize later)
nltk_stopwords = set(stopwords.words('english'))  # Replace with BM stopwords source if needed

# ✅ Step 5: Cleaning function using NLTK stopwords
def clean_text(text):
    text = text.lower()
    text = emoji.replace_emoji(text, replace='')                    # Remove emojis
    text = re.sub(r'[^a-zA-Z\s]', '', text)                         # Remove punctuation/digits
    text = re.sub(r'\s+', ' ', text).strip()                        # Normalize whitespace
    words = text.split()
    filtered_words = [word for word in words if word not in nltk_stopwords]
    return ' '.join(filtered_words)

# ✅ Step 6: Apply cleaning
df['review'] = df['review'].astype(str).apply(clean_text)

# ✅ Step 7: Clean and convert date format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# ✅ Step 8: Remove rows with empty review or missing date
df = df[df['review'].str.strip() != '']
df = df[df['date'].notna()]

# ✅ Step 9: Keep only relevant columns
df = df[['app', 'review', 'rating', 'sentiment', 'date']]

# ✅ Step 10: Save cleaned data
output_path = '/content/drive/MyDrive/Project2/cleaned_reviews.csv'
df.to_csv(output_path, index=False, encoding='utf-8-sig')

# ✅ Summary
print(f"✅ Cleaned data saved to Google Drive: {output_path}")
print(f"🧾 Final row count: {len(df)}")
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Cleaned data saved to Google Drive: /content/drive/MyDrive/Project2/cleaned_reviews.csv
# 🧾 Final row count: 100779
