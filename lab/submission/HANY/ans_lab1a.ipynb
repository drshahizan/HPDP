# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/HANY/ans_lab1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1a - Understanding Your Data

# %% [markdown]
# Please use the [**Chipotle Sales dataset**](https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv) for this exercise.

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as py

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv).

# %%
data = pd.read_csv('https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv',sep='\t')

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = data

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.shape[0]
# Out:
# 4622

# %%
# Solution 2
len(chipo)
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
num_columns = chipo.shape[1]
print(num_columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
column_names = chipo.columns

for column in column_names:
    print(column)
# Out:
# order_id
# quantity
# item_name
# choice_description
# item_price

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
item_counts = data.groupby('item_name')['quantity'].sum()

item_counts.idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo['item_name'].value_counts().max()
# Out:
# 726

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
choice_description_counts = data.groupby('choice_description')['quantity'].sum()

choice_description_counts.idxmax()
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
choice_description_counts.max()
# Out:
# 159

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
convert_float = lambda price: float(price[1:])

chipo['item_price'] = chipo['item_price'].apply(convert_float)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

chipo['revenue'] = chipo['item_price'] * chipo['quantity']
chipo['revenue'].sum()
# Out:
# 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
chipo['order_id'].nunique()
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
(chipo["quantity"] * chipo["item_price"] ).sum() / chipo["order_id"].nunique()
# Out:
# 21.39423118865867

# %%
# Solution 2
(chipo["quantity"]*chipo["item_price"]).groupby(chipo["order_id"]).sum().mean()
# Out:
# 21.39423118865867

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
chipo['item_name'].nunique()
# Out:
# 50
