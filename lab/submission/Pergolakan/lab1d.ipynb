# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/Pergolakan/lab1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab 1d - Filtering and Sorting Data**
# Please use the [**Chipotle Sales dataset**](https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv) for this exercise.
#
# ###Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [chipotle.tsv](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv)

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# We change the 'item_price' column from a string to a float type so that we can filtered out the products cost more than $10.00

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$', '')
chipo['item_price'] = chipo['item_price'].astype(float)
ip = np.count_nonzero(chipo['item_price'] > 10.00)

print("There is {} quantity of products that are more than $10.00.".format(ip))
# Out:
# There is 1130 quantity of products that are more than $10.00.

# %% [markdown]
# ### Step 5. What is the price of each item?
# print a data frame with only two columns item_name and item_price

# %%
chipo.groupby('item_name')[['item_price']].min().reset_index()
# Out:
#                                 item_name  item_price
# 0                       6 Pack Soft Drink        6.49
# 1                           Barbacoa Bowl        8.69
# 2                        Barbacoa Burrito        8.69
# 3                   Barbacoa Crispy Tacos        8.99
# 4                     Barbacoa Salad Bowl        9.39
# 5                     Barbacoa Soft Tacos        8.99
# 6                           Bottled Water        1.09
# 7                                    Bowl        7.40
# 8                                 Burrito        7.40
# 9                             Canned Soda        1.09
# 10                      Canned Soft Drink        1.25
# 11                          Carnitas Bowl        8.99
# 12                       Carnitas Burrito        8.69
# 13                  Carnitas Crispy Tacos        8.99
# 14                         Carnitas Salad        8.99
# 15                    Carnitas Salad Bowl        9.39
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
sortitem = chipo
sortitem.sort_values(by='item_name').reset_index()
# Out:
#       index  order_id  quantity          item_name  \
# 0      3389      1360         2  6 Pack Soft Drink
# 1       341       148         1  6 Pack Soft Drink
# 2      1849       749         1  6 Pack Soft Drink
# 3      1860       754         1  6 Pack Soft Drink
# 4      2713      1076         1  6 Pack Soft Drink
# ...     ...       ...       ...                ...
# 4617   2384       948         1  Veggie Soft Tacos
# 4618    781       322         1  Veggie Soft Tacos
# 4619   2851      1132         1  Veggie Soft Tacos
# 4620   1699       688         1  Veggie Soft Tacos
# 4621   1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 0                                           [Diet Coke]       12.98
# 1                                           [Diet Coke]        6.49
# 2                                                [Coke]        6.49
# 3                                           [Diet Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?
#
# First of all, from the table below we can see there is 3 items that have the highest price of all from the list and its quantity

# %%
chipo.groupby('item_name')[['item_price']].min().reset_index()
item_summary = chipo.groupby('item_name').agg({'item_price': 'min', 'quantity': 'sum'}).reset_index()
item_summary
# Out:
#                                 item_name  item_price  quantity
# 0                       6 Pack Soft Drink        6.49        55
# 1                           Barbacoa Bowl        8.69        66
# 2                        Barbacoa Burrito        8.69        91
# 3                   Barbacoa Crispy Tacos        8.99        12
# 4                     Barbacoa Salad Bowl        9.39        10
# 5                     Barbacoa Soft Tacos        8.99        25
# 6                           Bottled Water        1.09       211
# 7                                    Bowl        7.40         4
# 8                                 Burrito        7.40         6
# 9                             Canned Soda        1.09       126
# 10                      Canned Soft Drink        1.25       351
# 11                          Carnitas Bowl        8.99        71
# 12                       Carnitas Burrito        8.69        60
# 13                  Carnitas Crispy Tacos        8.99         8
# ...

# %% [markdown]
# We take the 3 most expensive items then we sum up the quantity of the order

# %%
exp = chipo[chipo['item_name'].isin(['Barbacoa Salad Bowl', 'Carnitas Salad Bowl', 'Steak Salad Bowl'])]
exp_chipo = exp['quantity'].sum()
print("There are {} numbers of the 3 most expensive items ".format(exp_chipo))
# Out:
# There are 47 numbers of the 3 most expensive items

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
vsb = chipo[chipo['item_name'] == 'Veggie Salad Bowl']
veggie = vsb.quantity.sum()
print("There are {} of times a Veggie Salad Bowl ordered by customer".format(veggie))
# Out:
# There are 18 of times a Veggie Salad Bowl ordered by customer

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
cSoda = chipo[chipo['item_name'] == 'Canned Soda']
cs = len(cSoda[cSoda['quantity'] > 1]) #filtered order more than one canned soda.
print("There are {} number of times someone order more than one Canned Soda." .format(cs) )
# Out:
# There are 20 number of times someone order more than one Canned Soda.
