# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/3H/lab1c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1c - Understanding Your Data

# %% [markdown]
# Please use the [**Open Food Facts**](https://www.kaggle.com/openfoodfacts/world-food-facts/data) dataset for this exercise.

# %% [markdown]
# ### Step 1. Download the dataset to your computer and unzip it.

# %%
import requests

headers = {"Cookie": "ka_sessionid=35834324d74c9956ee9d0f01f5f5c9ff; _ga=GA1.1.1968359825.1697593288; CSRF-TOKEN=CfDJ8Lu9ElOmQ3hFleDSXvQ7tt56PrFsihcUvKDWbrw67YtE7YVOj81dL7O1kM844ksezOMD802erd-SZYlBiD4kYkcVlPMAu7WhMPmZqCdmTw; __Host-KAGGLEID=CfDJ8Lu9ElOmQ3hFleDSXvQ7tt6RWHIGVPBQzwGwmWjY236t-Md2lXVdwQ3KVbFLno2XQN5iZsBjBp78Zcsfdk7wC_nLNzIsu9PsDEajFdn1Qnb2ueygrdgLlwxQ; GCLB=CNaIjPu77dbPKg; XSRF-TOKEN=CfDJ8Lu9ElOmQ3hFleDSXvQ7tt6DIX3CjBpc-_pXa27ZUsy2fw8OGsc2unDDO1FIuJ4cvSkdgVTUJBgzI4_FLPMBc4mxNbLRgIXPbGn7z_CxT14VsmAxVExf2_T2hj4MMQKXWhPsHBf7exEwn3qFW2D1B6w; CLIENT-TOKEN=eyJhbGciOiJub25lIiwidHlwIjoiSldUIn0.....; _ga_T7QHS60L4Q=GS1.1.1698653447.6.1.1698654676.0.0.0"}
r = requests.get("https://www.kaggle.com/datasets/openfoodfacts/world-food-facts/download?datasetVersionNumber=5", headers = headers)

# %%
with open("data.zip", "wb") as f:
  f.write(r.content)

del r

# %%
from zipfile import ZipFile
zip_file = ZipFile("/content/data.zip")
zip_file.extractall()

# %% [markdown]
# ### Step 2. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd

data = pd.read_table("/content/en.openfoodfacts.org.products.tsv")
# Out:
# <ipython-input-31-8e7e4e4cd02c>:3: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_table("/content/en.openfoodfacts.org.products.tsv")

# %% [markdown]
# ### Step 3. See the first 5 entries

# %%
data.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# ### Step 4. What is the number of observations in the dataset?

# %%
data.shape[0]
# Out:
# 356027

# %% [markdown]
# ### Step 5. What is the number of columns in the dataset?

# %%
data.shape[1]
# Out:
# 163

# %% [markdown]
# ### Step 6. Print the name of all the columns.

# %%
list(data.columns)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %% [markdown]
# ### Step 7. What is the name of 105th column?

# %%
data.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Step 8. What is the type of the observations of the 105th column?

# %%
data[ data.columns[104] ].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 9. How is the dataset indexed?

# %%
data.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Step 10. What is the product name of the 19th observation?

# %%
data.iloc[18,:]["product_name"]
# Out:
# 'Lotus Organic Brown Jasmine Rice'
