# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/SEK%20KITO/lab1/lab1b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 1b

# %% [markdown]
# ###Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###Step 2. Import the dataset from Occupation.
# ###Step 3. Assign it to a variable called users and use the 'user_id' as index

# %%
users = pd.read_csv('https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/u.user',sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.set_index('user_id')
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ###Step 4. See the first 25 entries

# %%
users.head(25)
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# ...

# %% [markdown]
# Step 5. See the last 10 entries

# %%
users.tail(10)
# Out:
#      user_id  age gender     occupation zip_code
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %% [markdown]
# ###Step 6. What is the number of observations in the dataset?

# %%
users.count
# Out:
# <bound method DataFrame.count of      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]>

# %% [markdown]
# ###Step 7. What is the number of columns in the dataset?

# %%
users.shape[1]
# Out:
# 5

# %% [markdown]
# ###Step 8. Print the name of all the columns.

# %%
users.columns
#print name of all columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %% [markdown]
# ###Step 9. How is the dataset indexed?

# %%
users.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %% [markdown]
# ###Step 10. What is the data type of each column?

# %%
column_data_types = users.dtypes

print(column_data_types)
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %% [markdown]
# ###Step 11. Print only the occupation colum

# %%
occupation_column = users['occupation']

print(occupation_column)
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %% [markdown]
# ###Step 12. How many different occupations are in this dataset?

# %%
users['occupation'].nunique()
# Out:
# 21

# %% [markdown]
# ###Step 13. What is the most frequent occupation?

# %%
users['occupation'].value_counts().idxmax()
# Out:
# 'student'

# %% [markdown]
# ###Step 14. Summarize the DataFrame.

# %%
users.describe #summmarize
# Out:
# <bound method NDFrame.describe of      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]>

# %% [markdown]
# ###Step 15. Summarize all the columns

# %%
users.info
# Out:
# <bound method DataFrame.info of      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]>

# %% [markdown]
# ###Step 16. Summarize only the occupation column

# %%
users['occupation'].describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %% [markdown]
# ###Step 17. What is the mean age of users?

# %%
users['age'].mean()
# Out:
# 34.05196182396607

# %% [markdown]
# ###Step 18. What is the age with least occurrence?

# %%
users['age'].value_counts().idxmin()
# Out:
# 7
