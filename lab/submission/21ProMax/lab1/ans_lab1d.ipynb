# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/21ProMax/lab1/ans_lab1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1d - Filtering and Sorting Data

# %% [markdown]
# Please use the [**Chipotle Sales dataset**](https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv) for this exercise.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', delimiter='\t')
chipo = pd.read_csv(url, sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
expensive_items = chipo[chipo['item_price'] > 10.00][['item_name', 'item_price']]
print(expensive_items)
print("The total number of products that cost more than $10.00: ", expensive_items.shape[0])
# Out:
#                item_name  item_price
# 4           Chicken Bowl       16.98
# 5           Chicken Bowl       10.98
# 7          Steak Burrito       11.75
# 13          Chicken Bowl       11.25
# 23       Chicken Burrito       10.98
# ...                  ...         ...
# 4610       Steak Burrito       11.75
# 4611      Veggie Burrito       11.25
# 4617       Steak Burrito       11.75
# 4618       Steak Burrito       11.75
# 4619  Chicken Salad Bowl       11.25
#
# [1130 rows x 2 columns]
# The total number of products that cost more than $10.00:  1130

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
unique_items_prices = chipo.drop_duplicates(subset=['item_name'])[['item_name', 'item_price']]
print(unique_items_prices)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 18                              Canned Soda        2.18
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 33                            Carnitas Bowl        8.99
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo[['item_name', 'item_price']].sort_values(by='item_name').drop_duplicates(subset=['item_name'])
# Out:
#                                   item_name  item_price
# 3389                      6 Pack Soft Drink       12.98
# 418                           Barbacoa Bowl        9.25
# 1202                       Barbacoa Burrito       11.75
# 1019                  Barbacoa Crispy Tacos        8.99
# 3546                    Barbacoa Salad Bowl       11.89
# 3548                    Barbacoa Soft Tacos       11.75
# 2441                          Bottled Water        7.50
# 673                                    Bowl        7.40
# 760                                 Burrito        7.40
# 1142                            Canned Soda        1.09
# 964                       Canned Soft Drink        1.25
# 1359                          Carnitas Bowl        8.99
# 1097                       Carnitas Burrito       11.75
# 554                   Carnitas Crispy Tacos        9.25
# 3750                         Carnitas Salad        8.99
# 2610                    Carnitas Salad Bowl       11.89
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
max_price = chipo['item_price'].max()
chipo[chipo['item_price'] == max_price][['item_name', 'quantity']]
# Out:
#                          item_name  quantity
# 3598  Chips and Fresh Tomato Salsa        15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie_bowl_orders = chipo[chipo['item_name'] == 'Veggie Salad Bowl']
print(veggie_bowl_orders.shape[0])
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
canned_soda_orders = chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)]
print(canned_soda_orders.shape[0])
# Out:
# 20
