# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/21ProMax/lab1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1d - Filtering and Sorting Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Please use the [**Chipotle Sales dataset**](https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv) for this exercise.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', delimiter='\t')
chipo = pd.read_csv(url, sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:-1]))
expensive_items = chipo[chipo['item_price'] > 10.00]
print(expensive_items.shape[0])
# Out:
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo[['item_name', 'item_price']].drop_duplicates(subset=['item_name'])
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 18                              Canned Soda        2.18
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 33                            Carnitas Bowl        8.99
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name').drop_duplicates(subset=['item_name'])
# Out:
#       order_id  quantity                              item_name  \
# 3389      1360         2                      6 Pack Soft Drink
# 418        182         1                          Barbacoa Bowl
# 1202       491         1                       Barbacoa Burrito
# 1019       419         1                  Barbacoa Crispy Tacos
# 3546      1426         1                    Barbacoa Salad Bowl
# 3548      1426         1                    Barbacoa Soft Tacos
# 2441       970         5                          Bottled Water
# 673        279         1                                   Bowl
# 760        313         1                                Burrito
# 1142       471         1                            Canned Soda
# 964        396         1                      Canned Soft Drink
# 1359       555         1                          Carnitas Bowl
# 1097       452         1                       Carnitas Burrito
# 554        230         1                  Carnitas Crispy Tacos
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
max_price = chipo['item_price'].max()
quantity = chipo[chipo['item_price'] == max_price]['quantity'].sum()
print(quantity)
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie_bowl_orders = chipo[chipo['item_name'] == 'Veggie Salad Bowl']
print(veggie_bowl_orders.shape[0])
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
canned_soda_orders = chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)]
print(canned_soda_orders.shape[0])
# Out:
# 20
