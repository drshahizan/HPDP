# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/HPDP/blob/main/lab/submission/MA1%20KTDI/lab1/ans_lab1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1d - Filtering and Sorting Data

# %% [markdown]
# Please use the [**Chipotle Sales dataset**](https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv) for this exercise.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
path = "https://raw.githubusercontent.com/drshahizan/dataset/main/pandas/chipotle.tsv"

chipo = pd.read_csv(path , sep = "\t")

chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.item_price.dtype
#type(chipo.columns[5])
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)
products = len(chipo[chipo['item_price'] > 10.0])
products
# Out:
# <ipython-input-42-279a1e131506>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo['priceEachItem'] = (chipo['item_price'] / chipo['quantity'])

print(chipo[['item_name' , 'priceEachItem']])
# Out:
#                                   item_name  priceEachItem
# 0              Chips and Fresh Tomato Salsa           2.39
# 1                                      Izze           3.39
# 2                          Nantucket Nectar           3.39
# 3     Chips and Tomatillo-Green Chili Salsa           2.39
# 4                              Chicken Bowl           8.49
# ...                                     ...            ...
# 4617                          Steak Burrito          11.75
# 4618                          Steak Burrito          11.75
# 4619                     Chicken Salad Bowl          11.25
# 4620                     Chicken Salad Bowl           8.75
# 4621                     Chicken Salad Bowl           8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
sorted_chipo = chipo.sort_values(by='item_name', ascending=True)
sorted_chipo
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
most_expensive_item = sorted_chipo.sort_values(by='item_price', ascending=False)
expitemloc = most_expensive_item.iloc[0]
Expitem = expitemloc['quantity']
print(Expitem)
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie = (chipo['item_name'] == "Veggie Salad Bowl").sum()
print(veggie)
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
cannedSoda = (chipo['item_name'] == "Canned Soda") & (chipo['quantity'] > 1 )
can = cannedSoda.sum()
print(can)
# Out:
# 20
