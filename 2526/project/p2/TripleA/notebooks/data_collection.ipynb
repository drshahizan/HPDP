# %%
# !pip install google-api-python-client pandas

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
API_KEY = "AIzaSyDUyUB9HEq9SUM7H2bciohTEYUGTdiJLwY"

# %%
youtube_links = [
    "https://www.youtube.com/watch?v=rakfl1KCaMk",
    "https://www.youtube.com/watch?v=rakfl1KCaMk",
    "https://www.youtube.com/watch?v=etTe2i4GkWo",
    "https://www.youtube.com/watch?v=_lZjm3mMl3g",
    "https://www.youtube.com/watch?v=qYZ22_54N9I",
    "https://www.youtube.com/watch?v=iVsn8X5K7pw",
    "https://www.youtube.com/watch?v=feDph2WgRfI",
    "https://www.youtube.com/watch?v=YyaXll-a6hs",
    "https://www.youtube.com/watch?v=s4uwJ-k3m0o",
    "https://www.youtube.com/watch?v=bF1VamLDso4",
    "https://www.youtube.com/watch?v=z73Ct-4pueo"

]

# %%
def get_video_id(url):
    if "watch?v=" in url:
        return url.split("watch?v=")[1].split("&")[0]
    return None

video_ids = [get_video_id(link) for link in youtube_links]

# %%
youtube = build(
    "youtube",
    "v3",
    developerKey=API_KEY
)

# %%
all_comments = []

for video_id in video_ids:

    try:

        next_page_token = None

        while True:

            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token
            )

            response = request.execute()

            for item in response["items"]:

                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]

                author = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]

                like_count = item["snippet"]["topLevelComment"]["snippet"]["likeCount"]

                published_at = item["snippet"]["topLevelComment"]["snippet"]["publishedAt"]

                all_comments.append({
                    "video_id": video_id,
                    "author": author,
                    "comment": comment,
                    "likes": like_count,
                    "published_at": published_at
                })

            next_page_token = response.get("nextPageToken")

            if not next_page_token:
                break

        print(f"Finished video: {video_id}")

    except Exception as e:
        print(f"Error for {video_id}: {e}")
# Out:
# Finished video: rakfl1KCaMk
# Finished video: rakfl1KCaMk
# Finished video: etTe2i4GkWo
# Finished video: _lZjm3mMl3g
# Finished video: qYZ22_54N9I
# Finished video: iVsn8X5K7pw
# Finished video: feDph2WgRfI
# Finished video: YyaXll-a6hs
# Finished video: s4uwJ-k3m0o
# Finished video: bF1VamLDso4
# Finished video: z73Ct-4pueo

# %%
df = pd.DataFrame(all_comments)

df.to_csv(
    "malaysia_food_comments.csv",
    index=False,
    encoding="utf-8-sig"
)

print("CSV saved successfully!")
# Out:
# CSV saved successfully!

# %%
from google.colab import files

files.download("malaysia_food_comments.csv")
